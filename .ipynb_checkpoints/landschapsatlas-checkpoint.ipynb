# %% [markdown]
# # Kastelenkaart: Landschapsatlas
#
# Visualisatie met betrekking tot kastelen en landgoederen

# %% [markdown]
# ## Initialisatie

# %%
# Downloader
import requests

# Dataprocessing
import pandas as pd
pd.options.display.max_rows = 10
from itertools import chain
import xml.etree.ElementTree as ET

# deal with shitty coordinates
import pyproj

# Display methods
import pprint
pp = pprint.PrettyPrinter(indent=1, width=80, depth=3, stream=None)

# Plotting library
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Download Landschapsatlas
#
# ### Metadata
#
# Spreek het basis WFS punt aan om die info te krijgen

# %%
# Download the XML
all_features = "http://services.rce.geovoorziening.nl/landschapsatlas/wfs?&request=GetCapabilities&service=WFS&SRSName=urn:x-ogc:def:crs:EPSG:4326"
resp = requests.get(all_features)
parsedXML = ET.fromstring(resp.text)

# Parse XML to usable list
featurelist = []
for item in parsedXML:
    if item.tag == "{http://www.opengis.net/wfs/2.0}FeatureTypeList":
        for subitem in item:
            for subitemProp in subitem:
                if subitemProp.tag == "{http://www.opengis.net/wfs/2.0}Name":
                    featurelist.append(subitemProp.text)

# %% [markdown]
# ### Get all features

# %%
# download data
feature_data = {}
for feature in featurelist:     
    link = f"http://services.rce.geovoorziening.nl/landschapsatlas/wfs?request=GetFeature&service=WFS&version=2.0.0&typeName={feature}&outputFormat=application%2Fjson"
    resp = requests.get(link)
    feature_data[feature] = resp.json()

# %%
# add buitenplaatsen
link = "http://services.rce.geovoorziening.nl/buitenplaatsen/wfs?request=GetFeature&service=WFS&version=2.0.0&typeName=Buitenplaatsen&outputFormat=json&SRSName=urn:x-ogc:def:crs:EPSG:4326"
resp = requests.get(link)
feature_data['buitenplaatsen'] = resp.json()

# %%
# summery = [f'{key}: {value["totalFeatures"]}' for key, value in feature_data.items()]
# pp = pprint.PrettyPrinter(indent=1, width=80, depth=3, stream=None)
# pp.pprint(feature_data['buitenplaatsen']["features"][:1])

# %% [markdown]
# ## Kastelen

# %%
# castles only
castles_list = [{"id": value["id"], **value["geometry"], **value["properties"]} for value in feature_data["landschapsatlas:kastelen"]["features"]]
castles_df = pd.DataFrame(castles_list)

estate_list = [{"id": value["id"], **value["geometry"], **value["properties"]} for value in feature_data["buitenplaatsen"]["features"]]
estate_df = pd.DataFrame(estate_list)

# %%
display(castles_df)
display(estate_df)
# Out:
#                                  bbox               bijschrift   cchin  \
# 0    [190380, 325970, 190380, 325970]          Albert Speelman  000007
# 1    [205620, 435270, 205620, 435270]          Albert Speelman  000009
# 2    [204250, 435700, 204250, 435700]          Albert Speelman  000010
# 3    [206750, 468190, 206750, 468190]          Albert Speelman  000011
# 4    [215970, 471310, 215970, 471310]          Albert Speelman  000014
# ..                                ...                      ...     ...
# 522    [31109, 387536, 31109, 387536]          Albert Speelman  001648
# 523    [31850, 391589, 31850, 391589]  Cyclomedia Globespotter  001865
# 524    [31103, 387534, 31103, 387534]          Albert Speelman  002024
# 525  [260174, 489770, 260174, 489770]  Cyclomedia Globespotter  002845
# 526    [93561, 441233, 93561, 441233]          Albert Speelman  003042
#
#           coordinates     datering  \
# 0    [190380, 325970]         1382
# 1    [205620, 435270]         1363
# 2    [204250, 435700]         1527
# 3    [206750, 468190]         1555
# 4    [215970, 471310]         1348
# ..                ...          ...
# 522   [31109, 387536]         1162
# 523   [31850, 391589]      875-900
# 524   [31103, 387534]      875-900
# 525  [260174, 489770]  9e/10e eeuw
# 526   [93561, 441233]         1426
#
#                                             foto_groot  \
# 0    https://images.memorix.nl/rce/thumb/1600x1600/...
# 1    https://images.memorix.nl/rce/thumb/1600x1600/...
# 2    https://images.memorix.nl/rce/thumb/1600x1600/...
# 3    https://images.memorix.nl/rce/thumb/1600x1600/...
# 4    https://images.memorix.nl/rce/thumb/1600x1600/...
# ..                                                 ...
# 522  https://images.memorix.nl/rce/thumb/1600x1600/...
# 523  https://images.memorix.nl/rce/thumb/1600x1600/...
# 524  https://images.memorix.nl/rce/thumb/1600x1600/...
# 525  https://images.memorix.nl/rce/thumb/1600x1600/...
# 526  https://images.memorix.nl/rce/thumb/1600x1600/...
#
#                                             foto_thumb  gid            id  \
# 0    https://images.memorix.nl/rce/thumb/350x350/51...    1    kastelen.1
# 1    https://images.memorix.nl/rce/thumb/350x350/c2...    2    kastelen.2
# 2    https://images.memorix.nl/rce/thumb/350x350/b9...    3    kastelen.3
# 3    https://images.memorix.nl/rce/thumb/350x350/2d...    4    kastelen.4
# 4    https://images.memorix.nl/rce/thumb/350x350/53...    5    kastelen.5
# ..                                                 ...  ...           ...
# 522  https://images.memorix.nl/rce/thumb/350x350/51...  523  kastelen.523
# 523  https://images.memorix.nl/rce/thumb/350x350/05...  524  kastelen.524
# 524  https://images.memorix.nl/rce/thumb/350x350/d2...  525  kastelen.525
# 525  https://images.memorix.nl/rce/thumb/350x350/c1...  526  kastelen.526
# 526  https://images.memorix.nl/rce/thumb/350x350/34...  527  kastelen.527
#
#                                         info_link  \
# 0    https://www.cchin.nl/index.xql?object=000007
# 1    https://www.cchin.nl/index.xql?object=000009
# 2    https://www.cchin.nl/index.xql?object=000010
# 3    https://www.cchin.nl/index.xql?object=000011
# 4    https://www.cchin.nl/index.xql?object=000014
# ..                                            ...
# 522  https://www.cchin.nl/index.xql?object=001648
# 523  https://www.cchin.nl/index.xql?object=001865
# 524  https://www.cchin.nl/index.xql?object=002024
# 525  https://www.cchin.nl/index.xql?object=002845
# 526  https://www.cchin.nl/index.xql?object=003042
#
#                           legenda                             naam  \
# 0                          Intact             De Dael / Oelsbroeck
# 1                          Intact    Huis Babberich  / Huis Halsaf
# 2                          Intact                       Camphuysen
# 3                          Intact  De (nieuwe) Poll / Huis Gietelo
# 4    Muurwerk in latere bebouwing                       Huis Dorth
# ..                            ...                              ...
# 522                       Restant       Oost-Souburg (ringwalburg)
# 523                   Ringwalburg           Ringwalburg Middelburg
# 524                   Ringwalburg         Ringwalburg Oost-Souburg
# 525                   Ringwalburg                 Volthe-Hunenborg
# 526                       Restant                  Huis Ten Berghe
#
#               plaats     provincie   rijksmonnr   type  \
# 0               Nuth       Limburg        30919  Point
# 1          Babberich    Gelderland       519901  Point
# 2       Oud-Zevenaar    Gelderland        40415  Point
# 3            Bussloo    Gelderland       530102  Point
# 4    Kring van Dorth    Gelderland       516389  Point
# ..               ...           ...          ...    ...
# 522     Oost-Souburg       Zeeland        46096  Point
# 523       Middelburg       Zeeland  Onbeschermd  Point
# 524     Oost-Souburg       Zeeland        46096  Point
# 525           Volthe    Overijssel        46005  Point
# 526    Hillegersberg  Zuid-Holland        32897  Point
#
#                          typering zichtbaar
# 0                          Intact         J
# 1                          Intact         J
# 2                          Intact         J
# 3                          Intact         J
# 4    Muurwerk in latere bebouwing         J
# ..                            ...       ...
# 522                       Ringwal         J
# 523                       Ringwal         J
# 524                       Ringwal         J
# 525                       Ringwal         J
# 526                         Ruïne         J
#
# [527 rows x 18 columns]
#                BEGRENSDAT    CENTROID_X    CENTROID_Y         Fotobijsch  \
# 0    2002-04-09T22:00:00Z  165449.19635  539860.00183      Beeldbank RCE
# 1    2002-04-09T22:00:00Z  141915.14572  476376.07917
# 2    2002-06-05T22:00:00Z  104194.53082  492993.46277    Albert Speelman
# 3    2002-10-29T23:00:00Z  157168.14618  457063.81908      Beeldbank RCE
# 4    2003-08-18T22:00:00Z  198651.78204  348544.90966      Beeldbank RCE
# ..                    ...           ...           ...                ...
# 528  2013-04-07T22:00:00Z  145416.09432  469833.92904    Albert Speelman
# 529  2013-04-09T22:00:00Z  167058.24578  443691.86370  Wikipedia Commons
# 530  2006-06-25T22:00:00Z  108555.58480  398740.43422      Beeldbank RCE
# 531  2013-04-09T22:00:00Z  184478.62658  491796.39539    Albert Speelman
# 532  2013-04-17T22:00:00Z  116946.09055  393875.68723    Albert Speelman
#
#                                              Fotogroot  \
# 0    https://images.memorix.nl/rce/thumb/fullsize/5...
# 1    http://rce.webgispublisher.nl/user/uploads/log...
# 2    https://images.memorix.nl/rce/thumb/fullsize/8...
# 3    https://images.memorix.nl/rce/thumb/fullsize/3...
# 4    https://images.memorix.nl/rce/thumb/fullsize/8...
# ..                                                 ...
# 528  https://images.memorix.nl/rce/thumb/fullsize/9...
# 529  http://upload.wikimedia.org/wikipedia/commons/...
# 530  https://images.memorix.nl/rce/thumb/fullsize/a...
# 531  https://images.memorix.nl/rce/thumb/fullsize/7...
# 532  https://images.memorix.nl/rce/thumb/fullsize/e...
#
#                                              Fotothumb  GEO_ID  \
# 0    https://images.memorix.nl/rce/thumb/350x350/5f...     141
# 1    http://rce.webgispublisher.nl/user/uploads/log...     130
# 2    https://images.memorix.nl/rce/thumb/350x350/8e...     157
# 3    https://images.memorix.nl/rce/thumb/350x350/3f...      52
# 4    https://images.memorix.nl/rce/thumb/350x350/87...      35
# ..                                                 ...     ...
# 528  https://images.memorix.nl/rce/thumb/350x350/95...    2121
# 529  http://upload.wikimedia.org/wikipedia/commons/...    1764
# 530  https://images.memorix.nl/rce/thumb/350x350/ab...     192
# 531  https://images.memorix.nl/rce/thumb/350x350/78...    2122
# 532  https://images.memorix.nl/rce/thumb/350x350/ea...    2123
#
#                 INSCHRIJF         NAAM ONDERGROND  OPPERV_HA  OPPERV_KM2  \
# 0    2003-05-26T22:00:00Z   Riniastate   LKI/GBKN      3.824       0.038
# 1    2002-03-03T23:00:00Z  Oud Crailoo   LKI/GBKN      3.649       0.036
# 2    2001-05-21T22:00:00Z   Spaarnberg   LKI/GBKN     19.301       0.193
# 3    2004-09-12T22:00:00Z      De Boom   LKI/GBKN     30.095       0.301
# 4    2006-09-04T22:00:00Z    Aerwinkel   LKI/GBKN     50.316       0.503
# ..                    ...          ...        ...        ...         ...
# 528  1999-10-12T22:00:00Z   Groeneveld   LKI/GBKN    107.474       1.075
# 529  1999-04-21T22:00:00Z  Remmerstein   LKI/GBKN      7.327       0.073
# 530  2006-12-20T23:00:00Z    Zoudtland   LKI/GBKN     15.701       0.157
# 531  2004-06-13T22:00:00Z   Klarenbeek   LKI/GBKN     17.241       0.172
# 532  1995-10-09T23:00:00Z   Valkenberg   LKI/GBKN    100.570       1.006
#
#        OPPERV_M2  RIJKSMONNR     STATUS  \
# 0      38236.045      526280  juridisch
# 1      36488.236      524269  juridisch
# 2     193005.764      512284  juridisch
# 3     300954.234      524207  juridisch
# 4     503159.237      527760  juridisch
# ..           ...         ...        ...
# 528  1074739.155      511772  juridisch
# 529    73267.370      509899  juridisch
# 530   157005.702      515501  juridisch
# 531   172405.087      512015  juridisch
# 532  1005699.690      490840  juridisch
#
#                                                    URL  \
# 0    https://monumentenregister.cultureelerfgoed.nl...
# 1    https://monumentenregister.cultureelerfgoed.nl...
# 2    https://monumentenregister.cultureelerfgoed.nl...
# 3    https://monumentenregister.cultureelerfgoed.nl...
# 4    https://monumentenregister.cultureelerfgoed.nl...
# ..                                                 ...
# 528  https://monumentenregister.cultureelerfgoed.nl...
# 529  https://monumentenregister.cultureelerfgoed.nl...
# 530  https://monumentenregister.cultureelerfgoed.nl...
# 531  https://monumentenregister.cultureelerfgoed.nl...
# 532  https://monumentenregister.cultureelerfgoed.nl...
#
#                                                   bbox  \
# 0    [52.844679694625604, 5.540002479185526, 52.847...
# 1    [52.274082504259255, 5.192496376618256, 52.275...
# 2    [52.41992522493346, 4.635458347834756, 52.4256...
# 3    [52.0970362262511, 5.41439447124945, 52.106101...
# 4    [51.11999115608892, 6.001791878572474, 51.1316...
# ..                                                 ...
# 528  [52.21279823418924, 5.231688570883146, 52.2214...
# 529  [51.98032078635346, 5.559441689911281, 51.9826...
# 530  [51.573436955411125, 4.713440038729752, 51.577...
# 531  [52.40925452251223, 5.816005441884884, 52.4180...
# 532  [51.52657537488257, 4.828018218013999, 51.5405...
#
#                                            coordinates                  id  \
# 0    [[[[52.844679694625604, 5.543712494949765], [5...    Buitenplaatsen.1
# 1    [[[[52.27582908220688, 5.193973434506232], [52...    Buitenplaatsen.2
# 2    [[[[52.42276620732263, 4.638271302035457], [52...    Buitenplaatsen.3
# 3    [[[[52.105844477499296, 5.421913705318745], [5...    Buitenplaatsen.4
# 4    [[[[51.12874000258445, 6.013440848177757], [51...    Buitenplaatsen.5
# ..                                                 ...                 ...
# 528  [[[[52.21326870943654, 5.246575745835755], [52...  Buitenplaatsen.529
# 529  [[[[51.982154573880564, 5.559441689911281], [5...  Buitenplaatsen.530
# 530  [[[[51.57779895230841, 4.719776520402702], [51...  Buitenplaatsen.531
# 531  [[[[52.416153250180514, 5.816005441884884], [5...  Buitenplaatsen.532
# 532  [[[[51.538138878909386, 4.842504707152574], [5...  Buitenplaatsen.533
#
#              type
# 0    MultiPolygon
# 1    MultiPolygon
# 2    MultiPolygon
# 3    MultiPolygon
# 4    MultiPolygon
# ..            ...
# 528  MultiPolygon
# 529  MultiPolygon
# 530  MultiPolygon
# 531  MultiPolygon
# 532  MultiPolygon
#
# [533 rows x 20 columns]

# %%
## Show all the images

# %%
from IPython.display import Image
from ipywidgets import GridBox, Layout, Image

images = [Image.from_url(image, layout=Layout(width='10px')) for image in estate_df["Fotothumb"]]
# images = [Image.from_url(image, layout=Layout(width='10px')) for image in estate_df["Fotothumb"][:10]]
for image in images:
    image.width = "100px"
    
display(GridBox(children=images, layout=Layout(
            width='100%',
            grid_template_rows='repeat(5, 110px)',
            grid_template_columns="repeat(10, 110px)")))
# Out:
# GridBox(children=(Image(value=b'https://images.memorix.nl/rce/thumb/350x350/5f1415b7-d7ab-e7b0-c889-962c28db31…

# %% [markdown]
# ## Generate map

# %%
# do conversions
from pyproj import CRS, Transformer

# setup conversions
crs_4326 = CRS.from_epsg(4326)
crs_28992 = CRS.from_epsg(28992)
transformer = Transformer.from_crs(crs_28992, crs_4326)

# %%
# estates
coords = estate_df.apply(lambda row: transformer.transform(row["CENTROID_X"], row["CENTROID_Y"]), axis=1)

# add to df
estate_df_geom = estate_df.copy()
estate_df_geom["centoid_lat"] = list(zip(*coords))[0]
estate_df_geom["centoid_lon"] = list(zip(*coords))[1]

# print the lat lon
# estate_df_geom

# %%
# castles
coords = castles_df.apply(lambda row: transformer.transform(row["coordinates"][0], row["coordinates"][1]), axis=1)

# add to df
castles_df_geom = castles_df.copy()
castles_df_geom["lat"] = list(zip(*coords))[0]
castles_df_geom["lon"] = list(zip(*coords))[1]

# print the lat lon
# castles_df_geom

# %%
def create_map_trace(lat, lon, color, name, text):
    return go.Scattermapbox(
            lat=lat,
            lon=lon,
            mode='markers',
            marker=go.scattermapbox.Marker(
                size=5,
                color=color
            ),
            name=name,
            text=text
        )
    

def create_map():
    mapbox_access_token = "pk.eyJ1IjoiemF0dXJyYnkiLCJhIjoiY2p3cmt3dGk3MWt5dTQ4bGU5NHR6bThwbSJ9.rqpHAUIbAXdex-iVEWsVdQ"
    
    estate_trace = create_map_trace(estate_df_geom["centoid_lat"], estate_df_geom["centoid_lon"], "green", "buitenplaatsen", estate_df_geom["NAAM"])
    castles_trace = create_map_trace(castles_df_geom["lat"], castles_df_geom["lon"],  "brown", "landschapsatlas:kastelen", castles_df_geom["naam"])
    
    fig = go.Figure([estate_trace, castles_trace])
    fig.update_layout(
        hovermode='closest',
        mapbox=go.layout.Mapbox(
            accesstoken=mapbox_access_token,
            bearing=0,
            center=go.layout.mapbox.Center(
                lat=52,
                lon=5
            ),
            pitch=0,
            zoom=7
        ),
        height=1000
    )

    return fig


iplot(create_map(), filename='map')
# display(create_map())

# %%
import chart_studio as cs
cs.tools.set_credentials_file(username='zaturrby', api_key='lMIugdWipeja7h1EHs50')
url = cs.plotly.plot(create_map(), filename='landgoed_1', sharing='secret', auto_open=False)

# %%
url
