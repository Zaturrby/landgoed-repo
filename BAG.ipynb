# %% [markdown]
# # Kastelenkaart: Kadaster en BAG
#
# Er zijn drie typen endpoints voor deze data. REST, SPARQL en WFS. Interessant om te kijken welke data waar zit. Moet je gewoon verkennen.
#
# [WFS catalogus] http://www.nationaalgeoregister.nl/geonetwork/srv/dut/catalog.search#/metadata/1c0dcc64-91aa-4d44-a9e3-54355556f5e7
#
# [BAG DATAMODEL] https://bag.basisregistraties.overheid.nl/datamodel
# [BAG DEF] https://bag.basisregistraties.overheid.nl/def/bag
#
# [BRT DATAMODEL] https://brt.basisregistraties.overheid.nl/datamodel
#
# https://github.com/tudelft3d/3dfier/wiki/General-3dfier-tutorial-to-generate-LOD1-models
# https://nlextract.nl

# %%
link = "https://geodata.nationaalgeoregister.nl/bag/wfs?request=GetFeature&service=WFS&version=2.0.0&typeName=bag:pand&outputFormat=csv"
df = pd.read_csv(link)
display(df)
# Out:
#            FID    identificatie  bouwjaar                            status  \
# 0       pand.1  828100001454586      1997                   Pand in gebruik
# 1       pand.2  828100001454587      1973                   Pand in gebruik
# 2       pand.3  828100001454589      1935                   Pand in gebruik
# 3       pand.4  828100001454590      1937                   Pand in gebruik
# 4       pand.5  828100001454592      1988                   Pand in gebruik
# 5       pand.6  398100000025259      1973                   Pand in gebruik
# 6       pand.7  828100001454593      1955                   Pand in gebruik
# 7       pand.8  828100001454594      1981                   Pand in gebruik
# 8       pand.9  828100001454595      1963                   Pand in gebruik
# 9      pand.10  828100001454597      1800                   Pand in gebruik
# 10     pand.11  828100001454625      1953                   Pand in gebruik
# ...
